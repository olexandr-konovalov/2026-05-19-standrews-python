# %% [markdown]
# # First session in Jupyter
#
# ## Jupyter is a sort of an IDE
#
# ### 19th May 2026
#
# - this
# - is
# - a list
#
# You can use *different* **formatting** `styles`
#
# Use `backtick` for code elements: names of files, functions, variables etc.
#
# ```
# this is
# several lines
# of code
# ```
#
# This is the page with [lesson reference](https://swcarpentry.github.io/python-novice-gapminder/reference.html)
#
# I can write mathematical formulas $\Sigma_{i=1}^{100}$

# %%
print("hello world!")
# Out:
# hello world!

# %%
age = 42
first_name = 'Ahmed'

# %%
print(first_name, 'is', age, 'years old')
# Out:
# Ahmed is 42 years old

# %%
1+1
# Out:
# 2
