# %% [markdown]
# # Working with strings

# %%
atom_name = 'helium'
print(atom_name[0])
print(atom_name[1])
# Out:
# h
# e

# %%
atom_name = 'helium'
atom_name[0]
atom_name[1]
# Out:
# 'e'

# %%
n = '123'

# %%
print(n)
# Out:
# 123

# %%
n
# Out:
# '123'

# %%
atom_name = 'sodium'

# %%
atom_name[0:3]
# Out:
# 'sod'

# %%
len('helium')
# Out:
# 6

# %%
atom_name = 'sodium'

# %%
atom_name[-2:-3]
# Out:
# ''

# %%
atom_name[3:106]
# Out:
# 'ium'

# %%
my_string = 'Hello world!'

# %%
my_string.isupper()
# Out:
# False

# %%
my_string.upper()
# Out:
# 'HELLO WORLD!'

# %%
len(min('A','a'))
# Out:
# 1

# %%
my_string.upper().isupper()
# Out:
# True
