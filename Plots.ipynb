# %% [markdown]
# # Plots

# %%
import matplotlib.pyplot as plt

# %%
time = [0,1,2,3]

# %%
position = [0, 120, 180, 330]

# %%
plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
plt.show()
