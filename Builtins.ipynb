# %% [markdown]
# # Built-in functions

# %%
r1 = len('something')
print(r1)
# Out:
# 9

# %%
r2 = print('something')
print(r2)
# Out:
# something
# None

# %%
max(1,2,3)
# Out:
# 3

# %%
min('a','A','0')
# Out:
# '0'

# %%
max('a','A','0')
# Out:
# 'a'

# %%
max(1,'A')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 max(1,'A')
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %%
print()

# %%
round(3.72343523452346)
# Out:
# 4

# %%
round(3.72343523452346, 2)
# Out:
# 3.72

# %% [markdown]
# ## Errors

# %%
name = 'Some
# Out:
#   Cell In[10], line 1
#     name = 'Some
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
age = = 54
# Out:
#   Cell In[11], line 1
#     age = = 54
#           ^
# SyntaxError: invalid syntax

# %%
print("hello"
# Out:
#   Cell In[12], line 1
#     print("hello"
#                  ^
# _IncompleteInputError: incomplete input
